# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pyplot import imshow

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, RadioButtons

# %%
imdata = cv2.imread("./diff.png",0)
imshow(imdata)
@interact(val_max=(0,255,11))
def calc(val_max):
    cv2.adaptiveThreshold(imdata, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, val_max, 2)
    imshow(th)
# th = cv2.adaptiveThreshold(imdata, 30, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)
# Out:
# interactive(children=(IntSlider(value=121, description='val_max', max=255, step=11), Output()), _dom_classes=(…

# %%
imshow(th)
# def a(val):
#     print(val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7e1d739d5333> in <module>
# ----> 1 imshow(th)
#       2 # def a(val):
#       3 #     print(val)
#       4
#       5 # @interact(a, val_max=(0.1,0.5,0.1))
#
# NameError: name 'th' is not defined
